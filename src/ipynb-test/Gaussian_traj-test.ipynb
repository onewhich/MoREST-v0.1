# %%
from ase.io import read, iread, write

# %%
gaussian_traj_file = '../../../../fhicloud-wang/ML_potential/SOAP-GAP/AlF_scattering/single_traj/gjf.log'

# %%
gaussian_traj = read(gaussian_traj_file, index=':', format='gaussian-out')

# %%
write('gaussian_traj.xyz',gaussian_traj)
