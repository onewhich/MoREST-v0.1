# %%
import numpy as np

# %%
class velocity_Verlet:
    '''
    This class implements velocity Verlet algorithm to do microcanonical ensemble (NVE) sampling.
    MoREST.traj records the trajectory in an extended xyz format:
    ------------------------------------
    n_atoms
    total energy
    x1 y1 z1 force_x1 force_y1 force_z1
    ...
    ------------------------------------
    MoREST.geo records the initial xyz structure of the system
    MoREST.geo_new records the current xyz structure of the system
    '''
    
    def __init__(self, md_parameters):
        #self.md_parameters = np.load('MoREST_md_parameters.npy',allow_pickle=True).item()
        self.md_parameters = md_parameters
        if self.md_parameters['new_traj']:
            self.__log_traj = open('MoREST.traj','w')
        else:
            self.__log_traj = open('MoREST.traj','a')
            
        self.position = 
        self.force = 
        self.acceleration = 
        self.velocity =
        
    def generate(self):
        time_step = self.md_parameters['time_step']
        self.acceleration = 
        self.new_position = 
        self.new_aaceleration = 
        self.new_velocity =
        
    def read_potential(self):
        return self.force, self.energy
